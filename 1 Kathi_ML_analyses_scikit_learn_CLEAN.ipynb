# %%
# load the required libraries
import scipy # to calculate correlation
import pandas as pd # to use dataframe
import seaborn as sns # to make plots
import matplotlib.pyplot as plt # to make plots
import numpy as np
from sklearn.metrics import mean_absolute_error # to calculate MAE
from sklearn.model_selection import train_test_split, KFold # to create data splits
from scipy import stats

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr
from sklearn.metrics import explained_variance_score
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import GroupShuffleSplit
from sklearn.utils import shuffle
import joblib

from pathlib import Path
import os

import datetime

# %%
#### Define the conditions for which the analysis should run:

## Define analysis input of the structural volume tables:

## Define Time point
#time = 'Base'
time = '2yFU'
#time = '4yFU'

input_type = 'cortical_thickness_Desikan'

## Define whether the analysis is performed for the whole group, only boys or only girls:
group = 'whole_group'
#group = 'only_boys'
#group = 'only_girls'

confound = 'None'

## define analysis type:
analysis_type = 'scikit_learn'
#analysis_type = 'Julearn'

## define target variable:
#target = 'PhSeAbuse'
#target = 'NHT'
#target = 'PreSubExp'
target = 'HD'
#target = 'Scarcity'
#target = 'ParentPsych'
#target = 'SESrec'

#Available 2 year: Physical and Sexual Violence, Neighborhood Threat, Household Dysfunction, SES_rec

#number of repetitions you want to perform for the predictive models:
rep = 100

# %%
### define local data directory:

ABCD_data_directory = 'ABCD PATHNAME'

results_directory = 'RESULTSDIRECTORY PATHNAME'

### define new folder in results-directory:

#foldername = f"abcd_{time}_{target}_{group}_{input_type}"

foldername = f"abcd_UniqueSample_{target}_PredictAll_{time}_{group}_{input_type}"

full_path = os.path.join(results_directory,foldername)

Path(full_path).mkdir(parents=True, exist_ok=True)

# %%
#LOAD THE CORRECT FILE
FinalSample = pd.read_csv(results_directory +'FINAL SAMPLE PATHNAME', low_memory=False)

# %%
# split table for boys and girls:

# boys:
data_only_boys = FinalSample[FinalSample['demo_sex_v2'] == 1]

rows, cols = data_only_boys.shape
print(f"Dataframe containing only boys has {rows} rows and {cols} colums")

# girls:
data_only_girls = FinalSample[FinalSample['demo_sex_v2'] == 2]

rows, cols = data_only_girls.shape
print(f"Dataframe containing only girls has {rows} rows and {cols} colums")
# Out:
# Dataframe containing only boys has 2194 rows and 147 colums
# Dataframe containing only girls has 1892 rows and 147 colums

# %%
### define which kind of input and tables to use:
# define group and split data into train and test:

if group == 'whole_group':
    data = FinalSample
    
elif group == 'only_boys':
    data = data_only_boys
    
elif group == 'only_girls':
    data = data_only_girls
    
sites = data['site_id_l']
sites

counts_values_sites = data['site_id_l'].value_counts()
counts_values_sites
# Out:
# site_id_l
# site16    404
# site10    290
# site04    281
# site20    277
# site17    268
# site13    232
# site14    216
# site06    216
# site12    214
# site21    180
# site11    175
# site07    168
# site03    150
# site18    144
# site15    143
# site02    134
# site01    133
# site19    129
# site05    128
# site09    122
# site08     82
# Name: count, dtype: int64

# %%
# define the type of input:

if input_type == 'volumes_Desikan':
    
    input_data = data.filter(regex='smri_vol_cdk').drop(columns=['smri_vol_cdk_totallh', 'smri_vol_cdk_totalrh', 'smri_vol_cdk_total'])


elif input_type == 'volumes_Destrieux':

    columns_to_select = [f'mrisdp_{i}' for i in range(454, 602)]
    input_data = data[columns_to_select]


elif input_type == 'volumes_subcortical_volumes_aseg':

    list_include_subcortical_regions = ['smri_vol_scs_aal', 'smri_vol_scs_aar',                 # accumbens
                                        'smri_vol_scs_amygdalalh', 'smri_vol_scs_amygdalarh',   # amygdala
                                        'smri_vol_scs_caudatelh', 'smri_vol_scs_caudaterh',     # caudate
                                        'smri_vol_scs_crbcortexlh', 'smri_vol_scs_crbcortexrh', # cerebellum cortex
                                        'smri_vol_scs_vedclh', 'smri_vol_scs_vedcrh',           # ventral diencephalon
                                        'smri_vol_scs_hpuslh', 'smri_vol_scs_hpusrh',           # hippocampus
                                        'smri_vol_scs_pallidumlh', 'smri_vol_scs_pallidumrh',   # pallidum
                                        'smri_vol_scs_putamenlh', 'smri_vol_scs_putamenrh',     # putamen
                                        'smri_vol_scs_tplh',  'smri_vol_scs_tprh',]             # thalamus

    input_data = data[list_include_subcortical_regions]


elif input_type == 'cortical_thickness_Desikan':

    input_data = data.filter(regex='smri_thick_cdk').drop(columns=['smri_thick_cdk_meanlh', 'smri_thick_cdk_meanrh', 'smri_thick_cdk_mean'])
    

elif input_type == 'cortical_thickness_Destrieux':

    columns_to_select = [f'mrisdp_{i}' for i in range(1, 149)]
    input_data = data[columns_to_select]


elif input_type == 'surface_area_Desikan':

    input_data = data.filter(regex='smri_area_cdk').drop(columns=['smri_area_cdk_totallh', 'smri_area_cdk_totalrh', 'smri_area_cdk_total'])
    

elif input_type == 'surface_area_Destrieux':

    columns_to_select = [f'mrisdp_{i}' for i in range(303, 451)]
    input_data = data[columns_to_select]


input_data
# Out:
#       smri_thick_cdk_banksstslh  smri_thick_cdk_cdacatelh  \
# 0                         2.879                     2.514
# 1                         2.732                     2.850
# 2                         2.004                     2.582
# 3                         2.712                     2.672
# 4                         2.723                     2.998
# ...                         ...                       ...
# 4081                      2.856                     2.711
# 4082                      2.596                     2.439
# 4083                      2.796                     2.652
# 4084                      2.631                     2.721
# 4085                      2.560                     2.500
#
#       smri_thick_cdk_cdmdfrlh  smri_thick_cdk_cuneuslh  \
# 0                       2.826                    2.053
# 1                       2.894                    2.329
# 2                       2.807                    1.922
# 3                       2.635                    1.859
# 4                       2.881                    1.986
# ...                       ...                      ...
# 4081                    2.844                    2.037
# 4082                    2.866                    2.090
# 4083                    2.993                    1.867
# 4084                    2.929                    2.205
# 4085                    2.799                    2.115
#
#       smri_thick_cdk_ehinallh  smri_thick_cdk_fusiformlh  \
# 0                       3.224                      3.053
# 1                       3.141                      2.916
# 2                       3.282                      2.714
# 3                       3.276                      2.759
# 4                       3.463                      2.885
# ...                       ...                        ...
# 4081                    3.065                      2.709
# 4082                    2.845                      2.864
# 4083                    3.153                      2.756
# 4084                    3.217                      2.801
# 4085                    3.102                      2.788
#
#       smri_thick_cdk_ifpllh  smri_thick_cdk_iftmlh  smri_thick_cdk_ihcatelh  \
# 0                     2.744                  3.121                    2.495
# 1                     2.817                  2.819                    2.595
# 2                     2.395                  2.956                    2.454
# 3                     2.633                  2.893                    2.367
# 4                     2.726                  3.123                    2.756
# ...                     ...                    ...                      ...
# 4081                  2.750                  2.739                    2.558
# 4082                  2.686                  2.793                    2.107
# 4083                  2.802                  2.968                    2.182
# 4084                  2.469                  2.778                    2.398
# 4085                  2.680                  2.959                    2.449
#
#       smri_thick_cdk_locclh  ...  smri_thick_cdk_rracaterh  \
# 0                     2.240  ...                     2.799
# 1                     2.417  ...                     3.133
# 2                     2.197  ...                     3.137
# 3                     2.199  ...                     2.689
# 4                     2.334  ...                     2.891
# ...                     ...  ...                       ...
# 4081                  2.289  ...                     2.717
# 4082                  2.121  ...                     2.901
# 4083                  2.299  ...                     2.602
# 4084                  2.249  ...                     3.006
# 4085                  2.300  ...                     2.827
#
#       smri_thick_cdk_rrmdfrrh  smri_thick_cdk_sufrrh  smri_thick_cdk_suplrh  \
# 0                       2.587                  3.030                  2.565
# 1                       2.665                  3.152                  2.680
# 2                       2.449                  2.891                  2.373
# 3                       2.501                  2.913                  2.305
# 4                       2.705                  3.099                  2.366
# ...                       ...                    ...                    ...
# 4081                    2.634                  2.925                  2.458
# 4082                    2.476                  2.984                  2.484
# 4083                    2.621                  3.065                  2.544
# 4084                    2.461                  2.898                  2.420
# 4085                    2.517                  2.870                  2.546
#
#       smri_thick_cdk_sutmrh  smri_thick_cdk_smrh  smri_thick_cdk_frpolerh  \
# 0                     3.201                2.800                    3.108
# 1                     3.158                2.866                    3.349
# 2                     2.755                2.613                    3.225
# 3                     3.034                2.617                    2.737
# 4                     3.256                2.754                    2.817
# ...                     ...                  ...                      ...
# 4081                  3.067                2.860                    2.792
# 4082                  2.954                2.632                    2.885
# 4083                  2.995                2.758                    2.974
# 4084                  2.772                2.728                    2.824
# 4085                  3.094                2.917                    3.591
#
#       smri_thick_cdk_tmpolerh  smri_thick_cdk_trvtmrh  smri_thick_cdk_insularh
# 0                       3.743                   2.931                    3.321
# 1                       3.910                   2.785                    3.129
# 2                       3.445                   2.764                    3.254
# 3                       3.550                   2.433                    3.236
# 4                       4.111                   2.954                    3.158
# ...                       ...                     ...                      ...
# 4081                    4.194                   2.731                    3.112
# 4082                    3.474                   2.798                    3.292
# 4083                    3.823                   2.884                    3.242
# 4084                    3.247                   2.312                    3.035
# 4085                    3.588                   2.723                    3.188
#
# [4086 rows x 68 columns]

# %%
### correct for confounding variables if necessary:

if confound == 'ICV':

    # define list of variablenames to iterate through:
    variable_names = input_data.columns.tolist() 

    # Calculate the scaled values and save them in a new DataFrame called 'ICV_scaled_columns'
    ICV_scaled_columns = pd.DataFrame({
        f'{col}_ICV_scaled': input_data[col] / data['smri_vol_scs_intracranialv']
        for col in variable_names
    })

    X = ICV_scaled_columns


elif confound == 'None':
    X = input_data

X
# Out:
#       smri_thick_cdk_banksstslh  smri_thick_cdk_cdacatelh  \
# 0                         2.879                     2.514
# 1                         2.732                     2.850
# 2                         2.004                     2.582
# 3                         2.712                     2.672
# 4                         2.723                     2.998
# ...                         ...                       ...
# 4081                      2.856                     2.711
# 4082                      2.596                     2.439
# 4083                      2.796                     2.652
# 4084                      2.631                     2.721
# 4085                      2.560                     2.500
#
#       smri_thick_cdk_cdmdfrlh  smri_thick_cdk_cuneuslh  \
# 0                       2.826                    2.053
# 1                       2.894                    2.329
# 2                       2.807                    1.922
# 3                       2.635                    1.859
# 4                       2.881                    1.986
# ...                       ...                      ...
# 4081                    2.844                    2.037
# 4082                    2.866                    2.090
# 4083                    2.993                    1.867
# 4084                    2.929                    2.205
# 4085                    2.799                    2.115
#
#       smri_thick_cdk_ehinallh  smri_thick_cdk_fusiformlh  \
# 0                       3.224                      3.053
# 1                       3.141                      2.916
# 2                       3.282                      2.714
# 3                       3.276                      2.759
# 4                       3.463                      2.885
# ...                       ...                        ...
# 4081                    3.065                      2.709
# 4082                    2.845                      2.864
# 4083                    3.153                      2.756
# 4084                    3.217                      2.801
# 4085                    3.102                      2.788
#
#       smri_thick_cdk_ifpllh  smri_thick_cdk_iftmlh  smri_thick_cdk_ihcatelh  \
# 0                     2.744                  3.121                    2.495
# 1                     2.817                  2.819                    2.595
# 2                     2.395                  2.956                    2.454
# 3                     2.633                  2.893                    2.367
# 4                     2.726                  3.123                    2.756
# ...                     ...                    ...                      ...
# 4081                  2.750                  2.739                    2.558
# 4082                  2.686                  2.793                    2.107
# 4083                  2.802                  2.968                    2.182
# 4084                  2.469                  2.778                    2.398
# 4085                  2.680                  2.959                    2.449
#
#       smri_thick_cdk_locclh  ...  smri_thick_cdk_rracaterh  \
# 0                     2.240  ...                     2.799
# 1                     2.417  ...                     3.133
# 2                     2.197  ...                     3.137
# 3                     2.199  ...                     2.689
# 4                     2.334  ...                     2.891
# ...                     ...  ...                       ...
# 4081                  2.289  ...                     2.717
# 4082                  2.121  ...                     2.901
# 4083                  2.299  ...                     2.602
# 4084                  2.249  ...                     3.006
# 4085                  2.300  ...                     2.827
#
#       smri_thick_cdk_rrmdfrrh  smri_thick_cdk_sufrrh  smri_thick_cdk_suplrh  \
# 0                       2.587                  3.030                  2.565
# 1                       2.665                  3.152                  2.680
# 2                       2.449                  2.891                  2.373
# 3                       2.501                  2.913                  2.305
# 4                       2.705                  3.099                  2.366
# ...                       ...                    ...                    ...
# 4081                    2.634                  2.925                  2.458
# 4082                    2.476                  2.984                  2.484
# 4083                    2.621                  3.065                  2.544
# 4084                    2.461                  2.898                  2.420
# 4085                    2.517                  2.870                  2.546
#
#       smri_thick_cdk_sutmrh  smri_thick_cdk_smrh  smri_thick_cdk_frpolerh  \
# 0                     3.201                2.800                    3.108
# 1                     3.158                2.866                    3.349
# 2                     2.755                2.613                    3.225
# 3                     3.034                2.617                    2.737
# 4                     3.256                2.754                    2.817
# ...                     ...                  ...                      ...
# 4081                  3.067                2.860                    2.792
# 4082                  2.954                2.632                    2.885
# 4083                  2.995                2.758                    2.974
# 4084                  2.772                2.728                    2.824
# 4085                  3.094                2.917                    3.591
#
#       smri_thick_cdk_tmpolerh  smri_thick_cdk_trvtmrh  smri_thick_cdk_insularh
# 0                       3.743                   2.931                    3.321
# 1                       3.910                   2.785                    3.129
# 2                       3.445                   2.764                    3.254
# 3                       3.550                   2.433                    3.236
# 4                       4.111                   2.954                    3.158
# ...                       ...                     ...                      ...
# 4081                    4.194                   2.731                    3.112
# 4082                    3.474                   2.798                    3.292
# 4083                    3.823                   2.884                    3.242
# 4084                    3.247                   2.312                    3.035
# 4085                    3.588                   2.723                    3.188
#
# [4086 rows x 68 columns]

# %%
# define the target variable:

if target == 'PhSeAbuse':
    y = data['PhSeAbuseSUM']
    
elif target == 'NHT':
    y = data['NeighborhoodThreat']

elif target == 'PreSubExp':
    y = data['PreSubExp']
    
elif target == 'HD':
    y = data['HouseholdDysfunction']

elif target == 'Scarcity':
    y = data['Scarcity']

elif target == 'ParentPsych':
    y = data['ParentalPsychopathologyrecoded']

elif target == 'SESrec':
    y = data['flipped_income']

y
# Out:
# 0       0.0
# 1       1.0
# 2       1.0
# 3       3.0
# 4       0.0
#        ...
# 4081    0.0
# 4082    0.0
# 4083    0.0
# 4084    2.0
# 4085    1.0
# Name: HouseholdDysfunction, Length: 4086, dtype: float64

# %%
#For Baseline recodedses
#y_applied = data[['PhSeAbuseSUM', 'NeighborhoodThreat', 'PreSubExp', 'HouseholdDysfunction', 'Scarcity', 'ParentalPsychopathologyrecoded','flipped_income']]
#y_applied_datanames= ['PhSeAbuse','NHT', 'PreSubExp', 'HD', 'Scarcity', 'ParentPsych', 'SESrec']

#including INR
#y_applied = data[['PhSeAbuseSUM', 'NeighborhoodThreat', 'PreSubExp', 'HouseholdDysfunction', 'Scarcity', 'ParentalPsychopathologyrecoded','flipped_income', 'income_to_thresh']]
#y_applied_datanames= ['PhSeAbuse','NHT', 'PreSubExp', 'HD', 'Scarcity', 'ParentPsych', 'SESrec', 'INR']

#For 2y FU (no parental psychopathology, no scarcity, no prenatal substance exposure (only from baseline)
y_applied = data[['PhSeAbuseSUM', 'NeighborhoodThreat', 'HouseholdDysfunction','flipped_income']]
y_applied_datanames= ['PhSeAbuse','NHT', 'HD', 'SESrec']

#For 4y FU (no parental psychopathology, no scarcity, no prenatal substance exposure (only from baseline)
#y_applied = data[['NeighborhoodThreat', 'HouseholdDysfunction','flipped_income']]
#y_applied_datanames= ['NHT', 'HD', 'SESrec']

# %%
y
# Out:
# 0       0.0
# 1       1.0
# 2       1.0
# 3       3.0
# 4       0.0
#        ...
# 4081    0.0
# 4082    0.0
# 4083    0.0
# 4084    2.0
# 4085    1.0
# Name: HouseholdDysfunction, Length: 4086, dtype: float64

# %%
y_applied
# Out:
#       PhSeAbuseSUM  NeighborhoodThreat  HouseholdDysfunction  flipped_income
# 0              0.0                   8                   0.0               4
# 1              0.0                   4                   1.0              10
# 2              0.0                   4                   1.0               4
# 3              0.0                   1                   3.0               1
# 4              0.0                   5                   0.0               1
# ...            ...                 ...                   ...             ...
# 4081           0.0                   0                   0.0               4
# 4082           0.0                   4                   0.0               3
# 4083           0.0                   2                   0.0               2
# 4084           0.0                   3                   2.0               8
# 4085           0.0                   1                   1.0               2
#
# [4086 rows x 4 columns]

# %%
full_path
# Out:
# '/Users/kbrosch/Desktop/ML/abcd_UniqueSample_HD_PredictAll_2yFU_whole_group_cortical_thickness_Desikan'

# %%
## save input data for the model to work with the data in the computation of the Null-distribution:
#Elvisha does it make sense to save y applied, too?
X.to_csv(os.path.join(full_path, "input_X.csv"), index=False)
y.to_csv(os.path.join(full_path, "input_y.csv"), index=False)
y_applied.to_csv(os.path.join(full_path, "input_y_applied.csv"), index=False)
sites.to_csv(os.path.join(full_path, "input_sites.csv"), index=False)

np.save((full_path + '/input_X.npy'),X)
np.save((full_path + '/input_Y.npy'),y)
np.save((full_path + '/input_y_applied.npy'),y_applied)
np.save((full_path + '/input_input_sites.npy'),sites)

# %%
### set up predictive models:
                               
# Create a Pipeline including Scaling and Ridge Regression
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # normalize features; Standardize features by removing the mean and scaling to unit variance -> z = (x - u) / s
    ('ridge', Ridge(
            fit_intercept=True, # Whether to fit the intercept for this model. If set to false, no intercept will be used in calculations (i.e. X and y are expected to be centered).
            copy_X=True, # copy_Xbool, default=True; If True, X will be copied; else, it may be overwritten.
            max_iter=1000000, # Maximum number of iterations for conjugate gradient solver.
            #tol -> for ‘lsqr’: tol is set as atol and btol of scipy.sparse.linalg.lsqr, which control the norm of the residual vector in terms of the norms of matrix and coefficients. 
            solver='lsqr', # ‘lsqr’ uses the dedicated regularized least-squares routine scipy.sparse.linalg.lsqr. It is the fastest and uses an iterative procedure.
            positive=False, # default is false; When set to True, forces the coefficients to be positive. Only ‘lbfgs’ solver is supported in this case.
            random_state=None # default is None; Used when solver == ‘sag’ or ‘saga’ to shuffle the data.
    ))
])
    
    # Define the range of parameters for the GridSearch:

    #set hyperparameter grid space you want to search through for the model
    #adapted from the Thomas Yeo Lab Github: 
    #ThomasYeoLab/CBIG/blob/master/stable_projects/predict_phenotypes/He2019_KRDNN/KR_HCP/CBIG_KRDNN_KRR_HCP.m
param_grid = {
        'ridge__alpha': [0, 0.00001, 0.0001, 0.001, 0.004, 0.007, 0.01, 0.04, 0.07, 0.1, 0.4, 0.7, 1, 1.5, 2, 2.5, 3,
              3.5, 4, 5, 10, 15, 20, 30, 40, 50, 60, 70, 80, 100, 150, 200, 300, 500, 700, 1000, 2000, 
              3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]
    }

# %%
#create variables to store relevant data/output

#number of outcomes to predict
n_y_applied = y_applied.shape[1]


#create variables to store the results
#r^2 - coefficient of determination
r2_scores_list = np.zeros([n_y_applied, rep])
#explained variance
explained_variance_list = np.zeros([n_y_applied, rep])
#correlation between true and predicted (aka prediction accuracy)
corr_coeff_list_pearson = np.zeros([n_y_applied, rep])
corr_p_value_list_pearson = np.zeros([n_y_applied, rep])
#optimised alpha (hyperparameter)
#opt_alpha = np.zeros([n_y_applied, rep])
opt_alpha = []

#feature importance extracted from the model
#feature_names = X.columns
#feat_imp = np.zeros([n_y_applied, rep])
#feat_imp = []
#for when the feat weights get haufe-inverted
#featimp_haufe = np.zeros([n_y_applied, rep])
#featimp_haufe = []

#feature importance extracted from the model
feature_names = X.columns
feat_imp = pd.DataFrame(columns=feature_names)

# dataframe for feature importance with the specified number of columns
column_names = [f'Repetition{i+1}' for i in range(rep)]
featimp_haufev1_dataframe = pd.DataFrame(columns=column_names)

# %%
for p in range(rep):
    
        #print model # you're on
    print('Model %d' %(p+1))
    
        # Now you can use datetime functionalities
    current_time = datetime.datetime.now()
    print("Current Date and Time :",current_time)
    
        ### split data into training and test:
    
        # generate a single division (by using the next function) of the data X into training and test sets, with all data belonging to the same group site 
        # ending up either completely in the training set or in the test set. The indices of these data points are then stored 
        # in the variables train_inds and test_inds.
    train_indx, test_indx = next(GroupShuffleSplit(test_size=0.2, n_splits=1, random_state = p).split(X, groups=sites))
    
       # use .iloc[] to enable access to the rows of the DataFrame via the indices that were created with GroupShuffleSplit.
    X_train = X.iloc[train_indx]
    X_test = X.iloc[test_indx]
        
    y_train = y.iloc[train_indx] #applies to the previously selected target variable, i.e. y train
        
    sites_train = sites.iloc[train_indx]
    sites_test = sites.iloc[test_indx] 
    
        #create variables to store nested CV scores, and best parameters from hyperparameter optimisation
    best_scores = []
    best_params = []
    
       # Use GroupKFold for grouping according to sites
    group_kfold = GroupKFold(n_splits=5)

    print ("Optimising Models")
        
        # Performing the grid search with cross-validation taking into account the groups (sites)
    grid_search = GridSearchCV(pipeline, param_grid, cv=group_kfold, scoring='explained_variance')
    grid_search.fit(X_train, y_train, groups=sites_train)
    
        # Add the best Paramter and best score to the lists:
    best_params.append(grid_search.best_params_)
    best_scores.append(grid_search.best_score_)
    best_model = grid_search.best_estimator_
    
        # Print best Parameter and best score
    print("Best Parameter for this model: ", grid_search.best_params_)
    print("Best Score for this model: ", grid_search.best_score_)  
    print ("Evaluating Models")
    
        #save optimised alpha values
    opt_alpha.append(grid_search.best_params_['ridge__alpha'])

        ### predict on the test-data with the best performing model:
    
        # fit model:
    best_model = grid_search.best_estimator_
    best_model.fit(X_train, y_train)
    
    
        # make preditions for the test set:
    y_pred = best_model.predict(X_test)
    
    # iterate through y_applied to exchange y_test:
    for nr_iteration in range(n_y_applied):
        y_applied_target = y_applied.iloc[:, nr_iteration]
        print ("y_test: %s" % y_applied.columns[nr_iteration])

        y_test = y_applied_target.iloc[test_indx] #iterates through all other variables, picks different y-applied, i.e., y test
            
        #reassign to loop
        #evaluate model:
        r2_score = best_model.score(X_test,y_test)
        r2_scores_list[nr_iteration, p] = r2_score
        print("r2-score: ",r2_score)

        #compute explained variance:
        ev_score = explained_variance_score(y_test, y_pred)
        explained_variance_list[nr_iteration, p] = ev_score
        print("explained variance score: ",ev_score)


    # compute correlation between true and predicted values (prediction accuracy):
        correlation_pearson, p_value_pearson = pearsonr(y_test, y_pred)

        corr_coeff_list_pearson[nr_iteration, p] = correlation_pearson
        corr_p_value_list_pearson[nr_iteration, p] = p_value_pearson
    
        print(f"Pearson-Correlation of y_test and y_pred: {correlation_pearson}")
        print(f"P-value: {p_value_pearson}")
    
    
    ### Extract feature weights of best model:
    
    ridge_regressor = best_model.named_steps['ridge']
    coefficients = ridge_regressor.coef_

    #feat_imp.append(coefficients)
    feat_imp.loc[p] = coefficients


    ### extract feature importance:
    #compute Haufe-inverted feature weights
    #preds = []
    y_train_preds = best_model.predict(X_train).ravel()
    
    #print ("Haufe-Transforming Feature Weights")
    cov_x = []
    cov_y = []
    
    #cov x is the covariance of the x_train data - covariance of brain data for the training set
    cov_x = np.cov(np.transpose(X_train))
    #cov y is the covariance of the y_train predicted data - covariance of the predicted behavior for the training set
    cov_y = np.cov(y_train_preds)
    #### What is the y_train_preds? Wo wird das gespeichert?? ist es das gleiche wie y_train? (Hier werden ja als Trainings-Datensatz eigentlich keine Predictions durchgefuhrt?)
    ### to be able to do the matrix multiplication using matmul, the matrix of the feature importance needed to be transposed:
    feat_imp_T = np.transpose(coefficients)
   
    #haufe-transformed feature weight is the cov x multiplied by the feature weights
    #(from the trained model based on th training data) and then divided by cov y
    #v1 here is based on eqn 6 of paper
    featimp_haufev1 = np.matmul(cov_x,feat_imp_T)*(1/cov_y)
    featimp_haufev1_dataframe[f'Repetition{p+1}'] = featimp_haufev1

# Print the current group and target in bold
print(f"\033[1m\033[32m\033[4m {target} in {group}, {input_type} \033[0m")
# Out:
# Model 1
# Current Date and Time : 2025-05-10 23:14:19.233712
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0006841593940248192
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -6.964276910353372
# explained variance score:  -0.008639381557939751
# Pearson-Correlation of y_test and y_pred: 0.058335625953021567
# P-value: 0.08622147903472291
# y_test: NeighborhoodThreat
# r2-score:  -1.0281884131242842
# explained variance score:  -0.00019426739124095427
# Pearson-Correlation of y_test and y_pred: 0.0008715928578341414
# P-value: 0.9795667459411564
# y_test: HouseholdDysfunction
# r2-score:  0.0016896105338259915
# explained variance score:  0.0021810193414243395
# Pearson-Correlation of y_test and y_pred: 0.04803359553169603
# P-value: 0.15786153704585226
# y_test: flipped_income
# r2-score:  -1.2898134396879684
# explained variance score:  0.003563251029491399
# Pearson-Correlation of y_test and y_pred: 0.1446972620922226
# P-value: 1.9156887357122708e-05
# Model 2
# Current Date and Time : 2025-05-10 23:14:19.956119
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  0.0009129479900323201
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.5729545489017043
# explained variance score:  -0.016416320108156413
# Pearson-Correlation of y_test and y_pred: 0.0022836775229769044
# P-value: 0.9387953911714073
# y_test: NeighborhoodThreat
# r2-score:  -1.0813480790117889
# explained variance score:  0.002651439965431379
# Pearson-Correlation of y_test and y_pred: 0.0711882768526086
# P-value: 0.016548061438324758
# y_test: HouseholdDysfunction
# r2-score:  -0.013267736028017785
# explained variance score:  -0.002066534781318463
# Pearson-Correlation of y_test and y_pred: 0.004020916529397369
# P-value: 0.8924573340873677
# y_test: flipped_income
# r2-score:  -2.0725254529466213
# explained variance score:  0.007252202918493489
# Pearson-Correlation of y_test and y_pred: 0.19808152471352206
# P-value: 1.7338990712581628e-11
# Model 3
# Current Date and Time : 2025-05-10 23:14:20.621635
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0013911845023955038
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -0.912221745283996
# explained variance score:  0.002959422956606783
# Pearson-Correlation of y_test and y_pred: 0.05907542444205714
# P-value: 0.07650303934929645
# y_test: NeighborhoodThreat
# r2-score:  -1.2006916843298128
# explained variance score:  0.0030479317964182684
# Pearson-Correlation of y_test and y_pred: 0.10723860627963831
# P-value: 0.001273069208760075
# y_test: HouseholdDysfunction
# r2-score:  -0.001222375633121331
# explained variance score:  0.0006988206931545227
# Pearson-Correlation of y_test and y_pred: 0.029541933034968767
# P-value: 0.37603825956193243
# y_test: flipped_income
# r2-score:  -2.3078351117561984
# explained variance score:  0.004981552682299495
# Pearson-Correlation of y_test and y_pred: 0.19332266819553895
# P-value: 5.0093190506577256e-09
# Model 4
# Current Date and Time : 2025-05-10 23:14:21.293513
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.001227338606945505
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -6.162707278219752
# explained variance score:  -0.013317779667818774
# Pearson-Correlation of y_test and y_pred: 0.043390879470855626
# P-value: 0.1919372037175204
# y_test: NeighborhoodThreat
# r2-score:  -0.8361371410314355
# explained variance score:  0.0022301537525406534
# Pearson-Correlation of y_test and y_pred: 0.07775776314062346
# P-value: 0.019241986567439577
# y_test: HouseholdDysfunction
# r2-score:  0.0031440749664861656
# explained variance score:  0.0035239636993465995
# Pearson-Correlation of y_test and y_pred: 0.06302003231269701
# P-value: 0.057939057838056716
# y_test: flipped_income
# r2-score:  -1.6737348624153188
# explained variance score:  0.003864545932425578
# Pearson-Correlation of y_test and y_pred: 0.14003170701233844
# P-value: 2.3372232736886355e-05
# Model 5
# Current Date and Time : 2025-05-10 23:14:21.988631
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0011152397833973592
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.1827293058743282
# explained variance score:  -0.004139497404620052
# Pearson-Correlation of y_test and y_pred: 0.02248271132415065
# P-value: 0.48026170814354385
# y_test: NeighborhoodThreat
# r2-score:  -1.1294549582110345
# explained variance score:  0.002774959707208202
# Pearson-Correlation of y_test and y_pred: 0.09472900235320317
# P-value: 0.002877768228435284
# y_test: HouseholdDysfunction
# r2-score:  -0.0026022596500046014
# explained variance score:  -0.0007677618720125512
# Pearson-Correlation of y_test and y_pred: 0.013389249962698059
# P-value: 0.6742347322189919
# y_test: flipped_income
# r2-score:  -2.007064360940351
# explained variance score:  0.0037544894040594246
# Pearson-Correlation of y_test and y_pred: 0.137678927096958
# P-value: 1.4067390085534591e-05
# Model 6
# Current Date and Time : 2025-05-10 23:14:22.743095
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0017581623644324696
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -5.312879928734184
# explained variance score:  -0.010467001733614811
# Pearson-Correlation of y_test and y_pred: 0.03229756451602819
# P-value: 0.3385730928804723
# y_test: NeighborhoodThreat
# r2-score:  -0.9303510642891388
# explained variance score:  0.0031713302567799584
# Pearson-Correlation of y_test and y_pred: 0.1245864924541817
# P-value: 0.00021137106019235386
# y_test: HouseholdDysfunction
# r2-score:  -0.0012068259655442226
# explained variance score:  0.004089027230170461
# Pearson-Correlation of y_test and y_pred: 0.07724109904627835
# P-value: 0.021934015258537862
# y_test: flipped_income
# r2-score:  -1.881729984314486
# explained variance score:  0.004566365839423048
# Pearson-Correlation of y_test and y_pred: 0.20134578147583318
# P-value: 1.678476660682282e-09
# Model 7
# Current Date and Time : 2025-05-10 23:14:23.525410
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  0.0005673405567756751
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.451517316375099
# explained variance score:  0.004366055469539498
# Pearson-Correlation of y_test and y_pred: 0.06955594635834828
# P-value: 0.06267432701823873
# y_test: NeighborhoodThreat
# r2-score:  -1.0663204394955343
# explained variance score:  0.0031432501648619438
# Pearson-Correlation of y_test and y_pred: 0.10087812949743069
# P-value: 0.006863716550262484
# y_test: HouseholdDysfunction
# r2-score:  -0.010800019160961627
# explained variance score:  0.0007240340606124995
# Pearson-Correlation of y_test and y_pred: 0.031687540191159116
# P-value: 0.39686970841993807
# y_test: flipped_income
# r2-score:  -1.317355119548449
# explained variance score:  0.004301110002115638
# Pearson-Correlation of y_test and y_pred: 0.1461090766357919
# P-value: 8.615289214444173e-05
# Model 8
# Current Date and Time : 2025-05-10 23:14:24.248381
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0013767354339786042
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -3.9283590578998373
# explained variance score:  -0.0031266572335575393
# Pearson-Correlation of y_test and y_pred: 0.0467732472954822
# P-value: 0.17485632976103402
# y_test: NeighborhoodThreat
# r2-score:  -1.1196580798136089
# explained variance score:  0.0011680267450101534
# Pearson-Correlation of y_test and y_pred: 0.04971132399421274
# P-value: 0.14927654149406053
# y_test: HouseholdDysfunction
# r2-score:  0.003567409979069458
# explained variance score:  0.003668847214520543
# Pearson-Correlation of y_test and y_pred: 0.07038172211995639
# P-value: 0.04105271033306155
# y_test: flipped_income
# r2-score:  -1.4784409833045293
# explained variance score:  0.003786368593887035
# Pearson-Correlation of y_test and y_pred: 0.17795003579793733
# P-value: 1.9866883327956245e-07
# Model 9
# Current Date and Time : 2025-05-10 23:14:24.954382
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  3.1586784999815265e-06
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.6795986764732835
# explained variance score:  0.0074038478231374105
# Pearson-Correlation of y_test and y_pred: 0.08609542914557658
# P-value: 0.014363172328507161
# y_test: NeighborhoodThreat
# r2-score:  -0.7997227322748612
# explained variance score:  0.002547313250386818
# Pearson-Correlation of y_test and y_pred: 0.10132061107296741
# P-value: 0.003938618892433957
# y_test: HouseholdDysfunction
# r2-score:  0.0026277665594516275
# explained variance score:  0.0045196188552476535
# Pearson-Correlation of y_test and y_pred: 0.078044951541334
# P-value: 0.026527275490244254
# y_test: flipped_income
# r2-score:  -1.2324233848259598
# explained variance score:  0.005963346745905818
# Pearson-Correlation of y_test and y_pred: 0.257073042075584
# P-value: 1.1610836105775826e-13
# Model 10
# Current Date and Time : 2025-05-10 23:14:25.648406
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  0.0013629800490689626
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.4376289606263408
# explained variance score:  -0.016369675338502532
# Pearson-Correlation of y_test and y_pred: -0.026059784933911003
# P-value: 0.41110362074904916
# y_test: NeighborhoodThreat
# r2-score:  -1.3761162205814488
# explained variance score:  0.0013973896294685595
# Pearson-Correlation of y_test and y_pred: 0.045331411105042047
# P-value: 0.15263297307629575
# y_test: HouseholdDysfunction
# r2-score:  -0.006162144535386327
# explained variance score:  -0.002774894832852315
# Pearson-Correlation of y_test and y_pred: -0.0011427449208142315
# P-value: 0.9712526424707411
# y_test: flipped_income
# r2-score:  -1.7216381147796236
# explained variance score:  0.003854651178417212
# Pearson-Correlation of y_test and y_pred: 0.13040183154800722
# P-value: 3.628279398515988e-05
# Model 11
# Current Date and Time : 2025-05-10 23:14:26.325153
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.00250787227806164
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -3.4400981846968604
# explained variance score:  -0.0011072205364173193
# Pearson-Correlation of y_test and y_pred: 0.04881269973711291
# P-value: 0.16647724188525498
# y_test: NeighborhoodThreat
# r2-score:  -1.3201126535859014
# explained variance score:  0.0015453917147391083
# Pearson-Correlation of y_test and y_pred: 0.07070192308734319
# P-value: 0.044921928087064925
# y_test: HouseholdDysfunction
# r2-score:  0.0034413992515220926
# explained variance score:  0.004317651635883157
# Pearson-Correlation of y_test and y_pred: 0.08367443148570877
# P-value: 0.01757127005717423
# y_test: flipped_income
# r2-score:  -1.6088852323477147
# explained variance score:  0.0037837868821797294
# Pearson-Correlation of y_test and y_pred: 0.20888215099237803
# P-value: 2.1848903117967933e-09
# Model 12
# Current Date and Time : 2025-05-10 23:14:27.009899
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 4000}
# Best Score for this model:  0.004474305756175778
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.009186373623252
# explained variance score:  -0.009892228398218794
# Pearson-Correlation of y_test and y_pred: 0.03462631097971236
# P-value: 0.22230512437976366
# y_test: NeighborhoodThreat
# r2-score:  -1.1315716667213334
# explained variance score:  0.0030694627652161355
# Pearson-Correlation of y_test and y_pred: 0.0684227907360456
# P-value: 0.01579140842704871
# y_test: HouseholdDysfunction
# r2-score:  -0.00876017609996027
# explained variance score:  -0.0031850172656253672
# Pearson-Correlation of y_test and y_pred: 0.010357771277517457
# P-value: 0.715137452568712
# y_test: flipped_income
# r2-score:  -1.931198695520608
# explained variance score:  0.007886306363073525
# Pearson-Correlation of y_test and y_pred: 0.17092173530805305
# P-value: 1.3022990922149029e-09
# Model 13
# Current Date and Time : 2025-05-10 23:14:27.708626
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0025277414753091198
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.7118425548445972
# explained variance score:  -0.01479546887621841
# Pearson-Correlation of y_test and y_pred: -0.03127974647112766
# P-value: 0.33730251481772333
# y_test: NeighborhoodThreat
# r2-score:  -1.0018150417139742
# explained variance score:  -0.00035724388615521185
# Pearson-Correlation of y_test and y_pred: -0.0026034530482036086
# P-value: 0.9363631377474524
# y_test: HouseholdDysfunction
# r2-score:  0.002950019860766706
# explained variance score:  0.0029529299672520493
# Pearson-Correlation of y_test and y_pred: 0.05622675165674906
# P-value: 0.08440078374088739
# y_test: flipped_income
# r2-score:  -1.5904315058644793
# explained variance score:  0.002324017583649751
# Pearson-Correlation of y_test and y_pred: 0.09128106166678436
# P-value: 0.005028115430370001
# Model 14
# Current Date and Time : 2025-05-10 23:14:28.430075
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.001061100270454296
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -5.149955981205707
# explained variance score:  -0.021188698159463115
# Pearson-Correlation of y_test and y_pred: 0.018183577073072096
# P-value: 0.6033221948476865
# y_test: NeighborhoodThreat
# r2-score:  -1.1484149545790485
# explained variance score:  -0.0015865033096007508
# Pearson-Correlation of y_test and y_pred: -0.04029419773796601
# P-value: 0.24938147275600936
# y_test: HouseholdDysfunction
# r2-score:  -0.0002842828145366294
# explained variance score:  0.00047717481180753474
# Pearson-Correlation of y_test and y_pred: 0.027199251592129402
# P-value: 0.43695352544166305
# y_test: flipped_income
# r2-score:  -1.3224078981316616
# explained variance score:  0.0019017534051249951
# Pearson-Correlation of y_test and y_pred: 0.07339807026874982
# P-value: 0.0357161772711764
# Model 15
# Current Date and Time : 2025-05-10 23:14:29.131535
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  0.003108671045070621
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -2.295201805146842
# explained variance score:  -0.027272579085406035
# Pearson-Correlation of y_test and y_pred: -0.011181649309746352
# P-value: 0.7130722531568345
# y_test: NeighborhoodThreat
# r2-score:  -1.1605430031445874
# explained variance score:  -0.00033423304331714476
# Pearson-Correlation of y_test and y_pred: 0.0043987495125988995
# P-value: 0.8849803329599747
# y_test: HouseholdDysfunction
# r2-score:  -0.017635037655439945
# explained variance score:  -0.003214323898993232
# Pearson-Correlation of y_test and y_pred: -0.006727211957688389
# P-value: 0.8249096662022717
# y_test: flipped_income
# r2-score:  -1.8624216914238185
# explained variance score:  0.005395146530413508
# Pearson-Correlation of y_test and y_pred: 0.14171623955119572
# P-value: 2.8110502076575347e-06
# Model 16
# Current Date and Time : 2025-05-10 23:14:29.823553
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0031432120377295368
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -5.115089696396986
# explained variance score:  -0.006297394374469523
# Pearson-Correlation of y_test and y_pred: 0.03677275908033205
# P-value: 0.24579240399332983
# y_test: NeighborhoodThreat
# r2-score:  -0.853675137698036
# explained variance score:  0.0018995140618038864
# Pearson-Correlation of y_test and y_pred: 0.08232756590324852
# P-value: 0.009268722072730363
# y_test: HouseholdDysfunction
# r2-score:  0.0018140197495377652
# explained variance score:  0.002864238734429314
# Pearson-Correlation of y_test and y_pred: 0.060800359358026045
# P-value: 0.05484249230160553
# y_test: flipped_income
# r2-score:  -1.8408517320924167
# explained variance score:  0.0027671430910034545
# Pearson-Correlation of y_test and y_pred: 0.13362848570581498
# P-value: 2.2835550821971352e-05
# Model 17
# Current Date and Time : 2025-05-10 23:14:30.545117
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0009217699686019598
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.0313847520226873
# explained variance score:  0.0016494315738423415
# Pearson-Correlation of y_test and y_pred: 0.052027581674486297
# P-value: 0.1330523427639412
# y_test: NeighborhoodThreat
# r2-score:  -0.9106185617830043
# explained variance score:  0.0029540292177512306
# Pearson-Correlation of y_test and y_pred: 0.09796498229589741
# P-value: 0.0046054374177606616
# y_test: HouseholdDysfunction
# r2-score:  -3.189893315913572e-05
# explained variance score:  5.517502109031458e-05
# Pearson-Correlation of y_test and y_pred: 0.02301101882872606
# P-value: 0.5066732472708333
# y_test: flipped_income
# r2-score:  -1.8218443132024023
# explained variance score:  0.005124312678049248
# Pearson-Correlation of y_test and y_pred: 0.18868976505977259
# P-value: 3.935933242604862e-08
# Model 18
# Current Date and Time : 2025-05-10 23:14:31.255891
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0027825988979049755
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.9716331033555279
# explained variance score:  -0.0049098718904245775
# Pearson-Correlation of y_test and y_pred: 0.0154238631735316
# P-value: 0.6211683474523042
# y_test: NeighborhoodThreat
# r2-score:  -1.4003358621151936
# explained variance score:  0.0013691432117579616
# Pearson-Correlation of y_test and y_pred: 0.062453682083291634
# P-value: 0.04518678737139067
# y_test: HouseholdDysfunction
# r2-score:  -0.0019478032053810157
# explained variance score:  0.0009760402919053446
# Pearson-Correlation of y_test and y_pred: 0.031242012555492832
# P-value: 0.3167260139229724
# y_test: flipped_income
# r2-score:  -1.8967240555206755
# explained variance score:  0.001960147635468368
# Pearson-Correlation of y_test and y_pred: 0.1072418504041805
# P-value: 0.000569228722242632
# Model 19
# Current Date and Time : 2025-05-10 23:14:31.962799
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0011401705806449725
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -2.7838347728055903
# explained variance score:  -0.019062756241246204
# Pearson-Correlation of y_test and y_pred: 0.0033202015674183884
# P-value: 0.9184260605803282
# y_test: NeighborhoodThreat
# r2-score:  -1.0530195979832278
# explained variance score:  0.0002389091320682546
# Pearson-Correlation of y_test and y_pred: 0.015626109726539262
# P-value: 0.6297785293821776
# y_test: HouseholdDysfunction
# r2-score:  -0.0034083734587511128
# explained variance score:  -0.0029052622632306235
# Pearson-Correlation of y_test and y_pred: -0.00799557546470972
# P-value: 0.8051879075037767
# y_test: flipped_income
# r2-score:  -1.9539820857057282
# explained variance score:  0.003403860558404359
# Pearson-Correlation of y_test and y_pred: 0.11687011527805859
# P-value: 0.00029754880142468905
# Model 20
# Current Date and Time : 2025-05-10 23:14:32.645555
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 7000}
# Best Score for this model:  0.006367890990663439
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.2489929753984503
# explained variance score:  -0.03286026104591766
# Pearson-Correlation of y_test and y_pred: -0.03476380219179285
# P-value: 0.21229536246542138
# y_test: NeighborhoodThreat
# r2-score:  -1.1662733281165107
# explained variance score:  0.002596016924986233
# Pearson-Correlation of y_test and y_pred: 0.0591012739662093
# P-value: 0.0338639243401038
# y_test: HouseholdDysfunction
# r2-score:  -0.01574912252211691
# explained variance score:  -0.012302387423497319
# Pearson-Correlation of y_test and y_pred: -0.05370254166959553
# P-value: 0.05390691312971856
# y_test: flipped_income
# r2-score:  -1.9572206565212853
# explained variance score:  0.00628820675581665
# Pearson-Correlation of y_test and y_pred: 0.13606348042266964
# P-value: 9.432724784688742e-07
# Model 21
# Current Date and Time : 2025-05-10 23:14:33.280835
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 8000}
# Best Score for this model:  -3.195126014474692e-05
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -7.433922941999235
# explained variance score:  -0.016564964230041834
# Pearson-Correlation of y_test and y_pred: 0.0637735396760272
# P-value: 0.051119694829777844
# y_test: NeighborhoodThreat
# r2-score:  -0.6566318398351227
# explained variance score:  0.004008327432873049
# Pearson-Correlation of y_test and y_pred: 0.11533046103952366
# P-value: 0.00040697004793909485
# y_test: HouseholdDysfunction
# r2-score:  -0.009901631903289854
# explained variance score:  0.0018222005403825126
# Pearson-Correlation of y_test and y_pred: 0.04336962558652014
# P-value: 0.18493705822273093
# y_test: flipped_income
# r2-score:  -1.579763831168158
# explained variance score:  0.006905130834291229
# Pearson-Correlation of y_test and y_pred: 0.20190384087425448
# P-value: 4.57244846788989e-10
# Model 22
# Current Date and Time : 2025-05-10 23:14:33.956671
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0020965314182312513
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -3.6143914425546253
# explained variance score:  -0.0029530164564126604
# Pearson-Correlation of y_test and y_pred: 0.04330428850453644
# P-value: 0.211281843515572
# y_test: NeighborhoodThreat
# r2-score:  -1.3701552036230433
# explained variance score:  0.0016809008753567722
# Pearson-Correlation of y_test and y_pred: 0.0759337199448678
# P-value: 0.02822894062527164
# y_test: HouseholdDysfunction
# r2-score:  -0.006187093691848222
# explained variance score:  0.0017125374248995184
# Pearson-Correlation of y_test and y_pred: 0.043396231409460584
# P-value: 0.21031306851945328
# y_test: flipped_income
# r2-score:  -1.411208947024989
# explained variance score:  0.0029800442316633147
# Pearson-Correlation of y_test and y_pred: 0.1642918772193818
# P-value: 1.8168797497989406e-06
# Model 23
# Current Date and Time : 2025-05-10 23:14:34.651823
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 7000}
# Best Score for this model:  0.004536096197245354
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.0903994591505537
# explained variance score:  -0.021430335343461726
# Pearson-Correlation of y_test and y_pred: -0.02378749113563777
# P-value: 0.38532762294089495
# y_test: NeighborhoodThreat
# r2-score:  -1.492493360551669
# explained variance score:  0.0038957510359229897
# Pearson-Correlation of y_test and y_pred: 0.09207662005216855
# P-value: 0.0007598924039021837
# y_test: HouseholdDysfunction
# r2-score:  -0.01159579865770044
# explained variance score:  -0.0052147307987062685
# Pearson-Correlation of y_test and y_pred: -0.015815321174895654
# P-value: 0.5638497296186376
# y_test: flipped_income
# r2-score:  -1.995598756809711
# explained variance score:  0.006932310959810062
# Pearson-Correlation of y_test and y_pred: 0.18222631338416798
# P-value: 2.005694654652439e-11
# Model 24
# Current Date and Time : 2025-05-10 23:14:35.306783
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  0.0018639965492048382
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -3.194710836281309
# explained variance score:  -0.013385723508545722
# Pearson-Correlation of y_test and y_pred: 0.0444168644809175
# P-value: 0.2446270245402952
# y_test: NeighborhoodThreat
# r2-score:  -1.0781269803975682
# explained variance score:  -0.0001954186353729792
# Pearson-Correlation of y_test and y_pred: 0.0042833153045224726
# P-value: 0.9107072277258006
# y_test: HouseholdDysfunction
# r2-score:  -0.004741321125922404
# explained variance score:  -0.004721683053946268
# Pearson-Correlation of y_test and y_pred: -0.016426050039521987
# P-value: 0.6671252139025964
# y_test: flipped_income
# r2-score:  -2.015168868265598
# explained variance score:  0.004836357736233365
# Pearson-Correlation of y_test and y_pred: 0.15834945405433376
# P-value: 3.0158503820756973e-05
# Model 25
# Current Date and Time : 2025-05-10 23:14:36.000743
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0015472592327586687
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.0994179791974994
# explained variance score:  -0.0029928330110955415
# Pearson-Correlation of y_test and y_pred: 0.01172765640816948
# P-value: 0.7084630729266671
# y_test: NeighborhoodThreat
# r2-score:  -1.080780866539743
# explained variance score:  0.0001846567580021663
# Pearson-Correlation of y_test and y_pred: 0.013610251486066543
# P-value: 0.6643245393261265
# y_test: HouseholdDysfunction
# r2-score:  -0.0014160135299781107
# explained variance score:  0.00461889806687632
# Pearson-Correlation of y_test and y_pred: 0.07835005939738066
# P-value: 0.012354615610122254
# y_test: flipped_income
# r2-score:  -1.5186240926448562
# explained variance score:  0.0002227083781410899
# Pearson-Correlation of y_test and y_pred: 0.015102174744830733
# P-value: 0.6301440964290667
# Model 26
# Current Date and Time : 2025-05-10 23:14:36.673849
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0013483978473159519
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.1746546658512629
# explained variance score:  0.002977820867939851
# Pearson-Correlation of y_test and y_pred: 0.05717166249801024
# P-value: 0.10744977673488361
# y_test: NeighborhoodThreat
# r2-score:  -1.0279176946828987
# explained variance score:  0.0015217834684999598
# Pearson-Correlation of y_test and y_pred: 0.06568744021131774
# P-value: 0.06431018252466975
# y_test: HouseholdDysfunction
# r2-score:  0.0012979050134119818
# explained variance score:  0.003711529481674969
# Pearson-Correlation of y_test and y_pred: 0.06926800578789365
# P-value: 0.05104477699248983
# y_test: flipped_income
# r2-score:  -1.8372679562165986
# explained variance score:  0.004061048223370722
# Pearson-Correlation of y_test and y_pred: 0.18926252405654342
# P-value: 7.731956141577876e-08
# Model 27
# Current Date and Time : 2025-05-10 23:14:37.368404
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  0.0034861818018926405
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.5487409454333183
# explained variance score:  -0.033237996061887154
# Pearson-Correlation of y_test and y_pred: -0.04792884356894092
# P-value: 0.09813265352307364
# y_test: NeighborhoodThreat
# r2-score:  -1.125944116996699
# explained variance score:  0.0027515511728399833
# Pearson-Correlation of y_test and y_pred: 0.06509596817681859
# P-value: 0.02460889718833757
# y_test: HouseholdDysfunction
# r2-score:  -0.010788780325728942
# explained variance score:  -0.010537281850349522
# Pearson-Correlation of y_test and y_pred: -0.052109766817365434
# P-value: 0.07210691705098407
# y_test: flipped_income
# r2-score:  -1.9199363176498525
# explained variance score:  0.005277469025605663
# Pearson-Correlation of y_test and y_pred: 0.12002166346629123
# P-value: 3.260442797748596e-05
# Model 28
# Current Date and Time : 2025-05-10 23:14:38.039181
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0023811034133159213
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.270111647480241
# explained variance score:  -0.0072704816169457676
# Pearson-Correlation of y_test and y_pred: -0.013906687845834216
# P-value: 0.6728973606037095
# y_test: NeighborhoodThreat
# r2-score:  -1.5407265557569074
# explained variance score:  0.0009848147421263054
# Pearson-Correlation of y_test and y_pred: 0.04576054516145969
# P-value: 0.16457585493461252
# y_test: HouseholdDysfunction
# r2-score:  -0.00010221680902589014
# explained variance score:  0.0037480063628078097
# Pearson-Correlation of y_test and y_pred: 0.07369243672585347
# P-value: 0.025086365960548036
# y_test: flipped_income
# r2-score:  -1.9095982820724964
# explained variance score:  0.0023224303387392453
# Pearson-Correlation of y_test and y_pred: 0.12154614962368729
# P-value: 0.00021271187511413562
# Model 29
# Current Date and Time : 2025-05-10 23:14:38.732343
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0026107590953002636
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.0611501731392785
# explained variance score:  -0.0013110665681737022
# Pearson-Correlation of y_test and y_pred: 0.0211726169624877
# P-value: 0.4894436176091927
# y_test: NeighborhoodThreat
# r2-score:  -1.057869846698456
# explained variance score:  0.00032301862127104286
# Pearson-Correlation of y_test and y_pred: 0.0192254412085719
# P-value: 0.5302562825949529
# y_test: HouseholdDysfunction
# r2-score:  0.0028790171166505063
# explained variance score:  0.004617510618210807
# Pearson-Correlation of y_test and y_pred: 0.08658377697714979
# P-value: 0.004631769247883383
# y_test: flipped_income
# r2-score:  -1.5317376822097106
# explained variance score:  0.001647689479156611
# Pearson-Correlation of y_test and y_pred: 0.083651878269356
# P-value: 0.006231208774991595
# Model 30
# Current Date and Time : 2025-05-10 23:14:39.558246
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 9000}
# Best Score for this model:  0.0025461182425652318
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.3667044170378198
# explained variance score:  -0.004978739980524338
# Pearson-Correlation of y_test and y_pred: 0.038147535637729754
# P-value: 0.20676776149546933
# y_test: NeighborhoodThreat
# r2-score:  -0.6934931610810857
# explained variance score:  0.0007013234677487601
# Pearson-Correlation of y_test and y_pred: 0.026789757044737267
# P-value: 0.3753746596658833
# y_test: HouseholdDysfunction
# r2-score:  -0.003990150497139577
# explained variance score:  -0.003944954548880553
# Pearson-Correlation of y_test and y_pred: -0.006962800126739379
# P-value: 0.8178161502732517
# y_test: flipped_income
# r2-score:  -1.7929869553662665
# explained variance score:  0.006207610741419067
# Pearson-Correlation of y_test and y_pred: 0.14993517430593722
# P-value: 6.082959514418614e-07
# Model 31
# Current Date and Time : 2025-05-10 23:14:40.456140
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.00030204676920508877
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -2.7777016820406466
# explained variance score:  -0.005973857288286366
# Pearson-Correlation of y_test and y_pred: 0.037618061366778255
# P-value: 0.3124442208769107
# y_test: NeighborhoodThreat
# r2-score:  -1.0642394975128666
# explained variance score:  0.001623833856520318
# Pearson-Correlation of y_test and y_pred: 0.06301046093048848
# P-value: 0.09045206886527755
# y_test: HouseholdDysfunction
# r2-score:  0.002306082905784934
# explained variance score:  0.002306395010218454
# Pearson-Correlation of y_test and y_pred: 0.04868330176593622
# P-value: 0.19102968884042124
# y_test: flipped_income
# r2-score:  -1.9883054953676744
# explained variance score:  0.004598761207997071
# Pearson-Correlation of y_test and y_pred: 0.19084786882662144
# P-value: 2.3364389428837018e-07
# Model 32
# Current Date and Time : 2025-05-10 23:14:41.200308
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  0.002119609468989303
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.5815018135594339
# explained variance score:  -0.014265361708078572
# Pearson-Correlation of y_test and y_pred: -0.0017072155188715835
# P-value: 0.9519561372129772
# y_test: NeighborhoodThreat
# r2-score:  -1.4561060926227527
# explained variance score:  0.001044836840316532
# Pearson-Correlation of y_test and y_pred: 0.037242515378263244
# P-value: 0.18857521094878787
# y_test: HouseholdDysfunction
# r2-score:  -0.014612545286817769
# explained variance score:  -0.0014694940256274602
# Pearson-Correlation of y_test and y_pred: 0.004978537484602106
# P-value: 0.8605281748913477
# y_test: flipped_income
# r2-score:  -1.8154705721096476
# explained variance score:  0.0053412711394768
# Pearson-Correlation of y_test and y_pred: 0.17813421150788528
# P-value: 2.336745876710896e-10
# Model 33
# Current Date and Time : 2025-05-10 23:14:41.912939
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.002034117268022895
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.7640339640060456
# explained variance score:  0.006378929623691354
# Pearson-Correlation of y_test and y_pred: 0.07986996786866803
# P-value: 0.015164317730250681
# y_test: NeighborhoodThreat
# r2-score:  -0.6586950642440166
# explained variance score:  0.0017532986212343005
# Pearson-Correlation of y_test and y_pred: 0.07437246153698701
# P-value: 0.023771739617834943
# y_test: HouseholdDysfunction
# r2-score:  -0.007813950464530706
# explained variance score:  0.004327415186597738
# Pearson-Correlation of y_test and y_pred: 0.07630980843669584
# P-value: 0.02034841456323137
# y_test: flipped_income
# r2-score:  -1.4533805406838303
# explained variance score:  0.0038551340109413967
# Pearson-Correlation of y_test and y_pred: 0.16636601536508952
# P-value: 3.6622382435724817e-07
# Model 34
# Current Date and Time : 2025-05-10 23:14:42.742807
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  0.0018546135280028907
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -2.4792922970858537
# explained variance score:  -0.02610658838577229
# Pearson-Correlation of y_test and y_pred: -0.022972593967899198
# P-value: 0.4647302980359575
# y_test: NeighborhoodThreat
# r2-score:  -1.250853770735381
# explained variance score:  0.0013781421485915546
# Pearson-Correlation of y_test and y_pred: 0.042898968306729235
# P-value: 0.1720439458274838
# y_test: HouseholdDysfunction
# r2-score:  -0.0030300734036210475
# explained variance score:  -0.0014613151885967124
# Pearson-Correlation of y_test and y_pred: 0.008446527729741707
# P-value: 0.7881053898690583
# y_test: flipped_income
# r2-score:  -1.8391278913258513
# explained variance score:  0.0051005171878207856
# Pearson-Correlation of y_test and y_pred: 0.1339493715287054
# P-value: 1.8559467635376138e-05
# Model 35
# Current Date and Time : 2025-05-10 23:14:43.527317
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.001714379255813281
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -6.914687454256348
# explained variance score:  -0.017984368425355335
# Pearson-Correlation of y_test and y_pred: 0.0411362147215391
# P-value: 0.21890156853315634
# y_test: NeighborhoodThreat
# r2-score:  -0.7131279718800201
# explained variance score:  0.0021463586591212724
# Pearson-Correlation of y_test and y_pred: 0.0727985120724977
# P-value: 0.029426389383707497
# y_test: HouseholdDysfunction
# r2-score:  -0.004656034016272681
# explained variance score:  -7.419864707736146e-05
# Pearson-Correlation of y_test and y_pred: 0.020878810779591243
# P-value: 0.5327477342467644
# y_test: flipped_income
# r2-score:  -1.5783190388665727
# explained variance score:  0.0035118365771855675
# Pearson-Correlation of y_test and y_pred: 0.11951804726815182
# P-value: 0.00033912138590169055
# Model 36
# Current Date and Time : 2025-05-10 23:14:44.392054
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0035732094071611264
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -4.823920843614431
# explained variance score:  -0.0033174506677557947
# Pearson-Correlation of y_test and y_pred: 0.05083708151146822
# P-value: 0.13428200903232707
# y_test: NeighborhoodThreat
# r2-score:  -1.0934152555281007
# explained variance score:  0.001393198275275842
# Pearson-Correlation of y_test and y_pred: 0.05880412159608864
# P-value: 0.08318822408169091
# y_test: HouseholdDysfunction
# r2-score:  0.0014467599893128735
# explained variance score:  0.004607768866831674
# Pearson-Correlation of y_test and y_pred: 0.08282112108528797
# P-value: 0.014600069468648136
# y_test: flipped_income
# r2-score:  -1.5915197278268192
# explained variance score:  0.0032479914629183204
# Pearson-Correlation of y_test and y_pred: 0.15043578037033123
# P-value: 8.44217580600666e-06
# Model 37
# Current Date and Time : 2025-05-10 23:14:45.106367
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0034923375624479115
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -2.099122002365595
# explained variance score:  -0.0034381788615203135
# Pearson-Correlation of y_test and y_pred: 0.020094037028977146
# P-value: 0.5075141734581866
# y_test: NeighborhoodThreat
# r2-score:  -1.2492354418223641
# explained variance score:  0.0020150774926250836
# Pearson-Correlation of y_test and y_pred: 0.10063786028683706
# P-value: 0.0008771970371128151
# y_test: HouseholdDysfunction
# r2-score:  -0.007486933360490333
# explained variance score:  0.0013845296313419464
# Pearson-Correlation of y_test and y_pred: 0.03873485917801059
# P-value: 0.201302552081509
# y_test: flipped_income
# r2-score:  -2.106843318888547
# explained variance score:  0.0023446832836364617
# Pearson-Correlation of y_test and y_pred: 0.13800254858719416
# P-value: 4.8115109658065535e-06
# Model 38
# Current Date and Time : 2025-05-10 23:14:45.792533
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0024253061963656953
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.0247812467026587
# explained variance score:  -0.004896826224418671
# Pearson-Correlation of y_test and y_pred: 0.009462677042416465
# P-value: 0.7652690856249059
# y_test: NeighborhoodThreat
# r2-score:  -1.0125988147782379
# explained variance score:  0.0028966821285041355
# Pearson-Correlation of y_test and y_pred: 0.09658925768902629
# P-value: 0.0022529682233816024
# y_test: HouseholdDysfunction
# r2-score:  0.001944729948740509
# explained variance score:  0.0019611800003123125
# Pearson-Correlation of y_test and y_pred: 0.044301536147530685
# P-value: 0.16197238843348477
# y_test: flipped_income
# r2-score:  -1.72031762146021
# explained variance score:  0.0026168692766045387
# Pearson-Correlation of y_test and y_pred: 0.09650423627660265
# P-value: 0.002273343805856234
# Model 39
# Current Date and Time : 2025-05-10 23:14:46.565888
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  0.0015345236242276573
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.2127356131978995
# explained variance score:  -0.0029563563825967254
# Pearson-Correlation of y_test and y_pred: 0.042899164102706125
# P-value: 0.1642062602359182
# y_test: NeighborhoodThreat
# r2-score:  -1.0182813473639736
# explained variance score:  0.0030709959654551255
# Pearson-Correlation of y_test and y_pred: 0.0845667871122944
# P-value: 0.00603544337016053
# y_test: HouseholdDysfunction
# r2-score:  -0.005100939366241786
# explained variance score:  -0.002692961524404014
# Pearson-Correlation of y_test and y_pred: 0.0009149066135090657
# P-value: 0.9763434543799389
# y_test: flipped_income
# r2-score:  -1.6892998009003914
# explained variance score:  0.005730348741596725
# Pearson-Correlation of y_test and y_pred: 0.15723200173374652
# P-value: 2.927738687967403e-07
# Model 40
# Current Date and Time : 2025-05-10 23:14:47.277097
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  0.002146395399126866
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -2.9740745037876835
# explained variance score:  -0.02461860944796923
# Pearson-Correlation of y_test and y_pred: -0.011810445639998796
# P-value: 0.6929716574711717
# y_test: NeighborhoodThreat
# r2-score:  -0.9045845188407513
# explained variance score:  -0.00034388775556504214
# Pearson-Correlation of y_test and y_pred: 0.0023362061325469634
# P-value: 0.9377507235438892
# y_test: HouseholdDysfunction
# r2-score:  -0.0029558716718964817
# explained variance score:  -0.0027692949365172304
# Pearson-Correlation of y_test and y_pred: -0.00421265254378354
# P-value: 0.888007784132585
# y_test: flipped_income
# r2-score:  -1.7779354688117563
# explained variance score:  0.004409478613590312
# Pearson-Correlation of y_test and y_pred: 0.12340921475669815
# P-value: 3.453579023749407e-05
# Model 41
# Current Date and Time : 2025-05-10 23:14:47.963872
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 8000}
# Best Score for this model:  0.0014780612471790634
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -6.319490118624406
# explained variance score:  0.005491743815039141
# Pearson-Correlation of y_test and y_pred: 0.11567224205040494
# P-value: 0.0007771906199327088
# y_test: NeighborhoodThreat
# r2-score:  -0.7985148896549432
# explained variance score:  0.0032810181766498303
# Pearson-Correlation of y_test and y_pred: 0.09865954941645151
# P-value: 0.0041851157464927345
# y_test: HouseholdDysfunction
# r2-score:  -0.006626876728307751
# explained variance score:  0.0012766623773476926
# Pearson-Correlation of y_test and y_pred: 0.03813846633013766
# P-value: 0.2692582036265358
# y_test: flipped_income
# r2-score:  -1.541432580767832
# explained variance score:  0.006525033447556172
# Pearson-Correlation of y_test and y_pred: 0.21400451280754468
# P-value: 3.6180219672984677e-10
# Model 42
# Current Date and Time : 2025-05-10 23:14:48.727801
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  0.0008198337947910473
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.0608756308304188
# explained variance score:  -0.000548788371031339
# Pearson-Correlation of y_test and y_pred: 0.046221460409229094
# P-value: 0.13576391353064207
# y_test: NeighborhoodThreat
# r2-score:  -0.9415898978122419
# explained variance score:  0.003127611769194183
# Pearson-Correlation of y_test and y_pred: 0.09473855406966197
# P-value: 0.0021923824785638622
# y_test: HouseholdDysfunction
# r2-score:  -0.011860052079432082
# explained variance score:  -8.09444649174651e-06
# Pearson-Correlation of y_test and y_pred: 0.022692373919010522
# P-value: 0.4641214049363789
# y_test: flipped_income
# r2-score:  -1.6579153228675958
# explained variance score:  0.008089579055744034
# Pearson-Correlation of y_test and y_pred: 0.2545659388336715
# P-value: 6.860633783098697e-17
# Model 43
# Current Date and Time : 2025-05-10 23:14:49.494373
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 7000}
# Best Score for this model:  0.005063042946225993
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -2.299832604880362
# explained variance score:  -0.058749085121714506
# Pearson-Correlation of y_test and y_pred: -0.047051237670498694
# P-value: 0.15011245913923757
# y_test: NeighborhoodThreat
# r2-score:  -1.2085191856125252
# explained variance score:  -0.0005217083104085418
# Pearson-Correlation of y_test and y_pred: 0.006377283807588122
# P-value: 0.8454297694574184
# y_test: HouseholdDysfunction
# r2-score:  -0.02027738989840211
# explained variance score:  -0.014432195723876662
# Pearson-Correlation of y_test and y_pred: -0.0716664737497841
# P-value: 0.028261571689458795
# y_test: flipped_income
# r2-score:  -1.9158742546572842
# explained variance score:  0.004929078349622529
# Pearson-Correlation of y_test and y_pred: 0.09783951771045946
# P-value: 0.0027165950730668876
# Model 44
# Current Date and Time : 2025-05-10 23:14:50.217954
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.002503447308639872
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.7961224910288887
# explained variance score:  0.00577247966765293
# Pearson-Correlation of y_test and y_pred: 0.07657434762783372
# P-value: 0.020322740231719785
# y_test: NeighborhoodThreat
# r2-score:  -0.9863761374105531
# explained variance score:  0.0016888913423234175
# Pearson-Correlation of y_test and y_pred: 0.06506636870268605
# P-value: 0.0487448154545598
# y_test: HouseholdDysfunction
# r2-score:  -0.0006082197673831224
# explained variance score:  0.002303550591055803
# Pearson-Correlation of y_test and y_pred: 0.04900460117333144
# P-value: 0.13790576537161786
# y_test: flipped_income
# r2-score:  -1.5406012953951564
# explained variance score:  0.0023161497268470166
# Pearson-Correlation of y_test and y_pred: 0.09247982933779235
# P-value: 0.005044238250969761
# Model 45
# Current Date and Time : 2025-05-10 23:14:51.004418
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  0.0008296154177829696
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.2049874610097921
# explained variance score:  -0.017725399016623067
# Pearson-Correlation of y_test and y_pred: -0.028359760388058746
# P-value: 0.325699344008475
# y_test: NeighborhoodThreat
# r2-score:  -1.360218137683752
# explained variance score:  0.0031604882617517482
# Pearson-Correlation of y_test and y_pred: 0.08739969764036112
# P-value: 0.0024129237091217726
# y_test: HouseholdDysfunction
# r2-score:  -0.00848865424088241
# explained variance score:  -0.0035303041127086043
# Pearson-Correlation of y_test and y_pred: -0.010546173397442921
# P-value: 0.7148005689415746
# y_test: flipped_income
# r2-score:  -1.9983247802633275
# explained variance score:  0.005481105707889067
# Pearson-Correlation of y_test and y_pred: 0.16916257113669325
# P-value: 3.5526392051134705e-09
# Model 46
# Current Date and Time : 2025-05-10 23:14:51.770687
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.001053038180554311
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -9.655929257857323
# explained variance score:  -0.014800343272790784
# Pearson-Correlation of y_test and y_pred: 0.05054139828367187
# P-value: 0.11798377097555382
# y_test: NeighborhoodThreat
# r2-score:  -0.6709274623499752
# explained variance score:  0.001060032309623371
# Pearson-Correlation of y_test and y_pred: 0.04184562537506245
# P-value: 0.19564335993449902
# y_test: HouseholdDysfunction
# r2-score:  -0.002347850745419322
# explained variance score:  0.003439937254606562
# Pearson-Correlation of y_test and y_pred: 0.06445339964976717
# P-value: 0.046107956101109474
# y_test: flipped_income
# r2-score:  -1.6300334872643911
# explained variance score:  0.004254875854039608
# Pearson-Correlation of y_test and y_pred: 0.16052916309186718
# P-value: 5.896744032268437e-07
# Model 47
# Current Date and Time : 2025-05-10 23:14:52.579137
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0005494654588861003
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -2.55309807304172
# explained variance score:  -0.00882006528913637
# Pearson-Correlation of y_test and y_pred: 0.039012685102897494
# P-value: 0.2428488605757296
# y_test: NeighborhoodThreat
# r2-score:  -0.9720228045740238
# explained variance score:  0.0008069911468724378
# Pearson-Correlation of y_test and y_pred: 0.030588096401786037
# P-value: 0.3598976056089782
# y_test: HouseholdDysfunction
# r2-score:  -0.004904111905449593
# explained variance score:  -0.003147280659988594
# Pearson-Correlation of y_test and y_pred: -0.009579060722620773
# P-value: 0.7743733642891683
# y_test: flipped_income
# r2-score:  -1.8543176483936117
# explained variance score:  0.005776081462100846
# Pearson-Correlation of y_test and y_pred: 0.19080418818658995
# P-value: 8.271926347277214e-09
# Model 48
# Current Date and Time : 2025-05-10 23:14:53.504181
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 5000}
# Best Score for this model:  0.0032245715528920636
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -3.322922347675277
# explained variance score:  -0.04281339673820295
# Pearson-Correlation of y_test and y_pred: -0.0026078687106059545
# P-value: 0.9266693343655482
# y_test: NeighborhoodThreat
# r2-score:  -0.829532870219827
# explained variance score:  0.0009706760049638108
# Pearson-Correlation of y_test and y_pred: 0.03129706717709327
# P-value: 0.2692481800104197
# y_test: HouseholdDysfunction
# r2-score:  -0.009036806185431567
# explained variance score:  -0.006528650397056968
# Pearson-Correlation of y_test and y_pred: -0.01565330631239152
# P-value: 0.580629977123428
# y_test: flipped_income
# r2-score:  -1.8786672970087457
# explained variance score:  0.004957517226119923
# Pearson-Correlation of y_test and y_pred: 0.10190116149610043
# P-value: 0.0003113741011066359
# Model 49
# Current Date and Time : 2025-05-10 23:14:54.218896
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  0.0016005763794585404
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.7875949819047774
# explained variance score:  -0.025453265257272983
# Pearson-Correlation of y_test and y_pred: -0.053752060216668895
# P-value: 0.11866506163630296
# y_test: NeighborhoodThreat
# r2-score:  -1.419126298684228
# explained variance score:  0.0015100096575193511
# ...
# Pearson-Correlation of y_test and y_pred: 0.13282600851117887
# P-value: 5.572294977713667e-05
# Model 85
# Current Date and Time : 2025-05-10 23:15:20.736245
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0013616298392360227
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.488320321502878
# explained variance score:  -0.0002548494681560154
# Pearson-Correlation of y_test and y_pred: 0.03984269785653817
# P-value: 0.20514194689898738
# y_test: NeighborhoodThreat
# r2-score:  -0.8281897951656345
# explained variance score:  0.002237762120323006
# Pearson-Correlation of y_test and y_pred: 0.08649824707076081
# P-value: 0.0058727600353353365
# y_test: HouseholdDysfunction
# r2-score:  -0.0009756755700727204
# explained variance score:  0.0006388403850124957
# Pearson-Correlation of y_test and y_pred: 0.027693775107640796
# P-value: 0.3785837956690834
# y_test: flipped_income
# r2-score:  -1.4988699554085296
# explained variance score:  0.0043389185307327605
# Pearson-Correlation of y_test and y_pred: 0.1857698245226781
# P-value: 2.5652223973551114e-09
# Model 86
# Current Date and Time : 2025-05-10 23:15:21.445580
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  0.0006609443624251865
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -2.912189072024792
# explained variance score:  -0.0146346801659889
# Pearson-Correlation of y_test and y_pred: 0.007974531833901868
# P-value: 0.77664837658131
# y_test: NeighborhoodThreat
# r2-score:  -0.797478018051941
# explained variance score:  0.00044038120073575104
# Pearson-Correlation of y_test and y_pred: 0.021396703245666907
# P-value: 0.4465073722979239
# y_test: HouseholdDysfunction
# r2-score:  -0.00046202155561370084
# explained variance score:  0.0003314032924279786
# Pearson-Correlation of y_test and y_pred: 0.02469621009320415
# P-value: 0.37957820522955427
# y_test: flipped_income
# r2-score:  -1.7840619442383971
# explained variance score:  0.004817698987333641
# Pearson-Correlation of y_test and y_pred: 0.16398223007873303
# P-value: 4.272495776980267e-09
# Model 87
# Current Date and Time : 2025-05-10 23:15:22.147684
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0024798781650215316
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -4.267569348299848
# explained variance score:  -0.0036521392957455934
# Pearson-Correlation of y_test and y_pred: 0.03957065558176274
# P-value: 0.22797483080880074
# y_test: NeighborhoodThreat
# r2-score:  -1.1984099897056009
# explained variance score:  0.00271055603493886
# Pearson-Correlation of y_test and y_pred: 0.12175335879194014
# P-value: 0.00019777699797574895
# y_test: HouseholdDysfunction
# r2-score:  0.004841437923915004
# explained variance score:  0.00486361087219167
# Pearson-Correlation of y_test and y_pred: 0.09330555514406923
# P-value: 0.004401915924864653
# y_test: flipped_income
# r2-score:  -1.8499214968577853
# explained variance score:  0.0033980963918656126
# Pearson-Correlation of y_test and y_pred: 0.17768729166377017
# P-value: 4.899758026254193e-08
# Model 88
# Current Date and Time : 2025-05-10 23:15:22.857008
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0008494146234621525
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -7.013285955364694
# explained variance score:  -0.014575188062312394
# Pearson-Correlation of y_test and y_pred: 0.05102470136663585
# P-value: 0.12696063924292814
# y_test: NeighborhoodThreat
# r2-score:  -0.7414279578186305
# explained variance score:  0.0013901751672283913
# Pearson-Correlation of y_test and y_pred: 0.04705096555457432
# P-value: 0.15936748632923536
# y_test: HouseholdDysfunction
# r2-score:  -0.03265943898846846
# explained variance score:  0.0005394953650817991
# Pearson-Correlation of y_test and y_pred: 0.02994666060493238
# P-value: 0.37059970074254955
# y_test: flipped_income
# r2-score:  -1.5417441769906644
# explained variance score:  0.005319487044938898
# Pearson-Correlation of y_test and y_pred: 0.1743426242769972
# P-value: 1.507611445462297e-07
# Model 89
# Current Date and Time : 2025-05-10 23:15:23.572606
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.00023627699082624521
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.652848603871786
# explained variance score:  0.006291122576749575
# Pearson-Correlation of y_test and y_pred: 0.07937103217384725
# P-value: 0.023196784923226816
# y_test: NeighborhoodThreat
# r2-score:  -0.893698054767395
# explained variance score:  0.0030001087963523743
# Pearson-Correlation of y_test and y_pred: 0.1182748384960259
# P-value: 0.0007002686102383439
# y_test: HouseholdDysfunction
# r2-score:  0.0027727448466953186
# explained variance score:  0.004892512796712212
# Pearson-Correlation of y_test and y_pred: 0.08269321718933467
# P-value: 0.01800478861375742
# y_test: flipped_income
# r2-score:  -1.3564429580008408
# explained variance score:  0.004452449794849045
# Pearson-Correlation of y_test and y_pred: 0.19311908238393544
# P-value: 2.5859063329064833e-08
# Model 90
# Current Date and Time : 2025-05-10 23:15:24.305418
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0010093630001642762
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -0.8569365266740088
# explained variance score:  -0.0039115790527453065
# Pearson-Correlation of y_test and y_pred: 0.014816888051792973
# P-value: 0.6377854426852283
# y_test: NeighborhoodThreat
# r2-score:  -1.1427428506764121
# explained variance score:  0.0032969311337412988
# Pearson-Correlation of y_test and y_pred: 0.10334011952054656
# P-value: 0.000994050067434243
# y_test: HouseholdDysfunction
# r2-score:  0.0009142988202799351
# explained variance score:  0.0009172573663689398
# Pearson-Correlation of y_test and y_pred: 0.0331195692540239
# P-value: 0.2925314008218178
# y_test: flipped_income
# r2-score:  -1.9314652339202847
# explained variance score:  0.0036446995262771065
# Pearson-Correlation of y_test and y_pred: 0.1296850181041102
# P-value: 3.504685591008698e-05
# Model 91
# Current Date and Time : 2025-05-10 23:15:25.015877
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0029628980430527196
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -10.626916268609326
# explained variance score:  -0.023878107887575384
# Pearson-Correlation of y_test and y_pred: 0.03872876986901649
# P-value: 0.23402410783812402
# y_test: NeighborhoodThreat
# r2-score:  -0.714547452026687
# explained variance score:  0.0018331370477271403
# Pearson-Correlation of y_test and y_pred: 0.06501928031885999
# P-value: 0.0455783823786837
# y_test: HouseholdDysfunction
# r2-score:  -0.008941454906365331
# explained variance score:  0.0029245838818919845
# Pearson-Correlation of y_test and y_pred: 0.056484595124180546
# P-value: 0.08249445837641883
# y_test: flipped_income
# r2-score:  -1.6730719958754228
# explained variance score:  0.0041066508157496795
# Pearson-Correlation of y_test and y_pred: 0.1409298204458153
# P-value: 1.3576934724601197e-05
# Model 92
# Current Date and Time : 2025-05-10 23:15:25.727013
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 9000}
# Best Score for this model:  0.0003177581379711247
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.3776002035042914
# explained variance score:  -0.0007724241273030508
# Pearson-Correlation of y_test and y_pred: 0.03924062799856325
# P-value: 0.20090459225543514
# y_test: NeighborhoodThreat
# r2-score:  -0.9366787986343876
# explained variance score:  0.0019369590724088726
# Pearson-Correlation of y_test and y_pred: 0.07277302657286384
# P-value: 0.017589762433571816
# y_test: HouseholdDysfunction
# r2-score:  -0.0001361638687289446
# explained variance score:  0.00042554668672156737
# Pearson-Correlation of y_test and y_pred: 0.02581705753529693
# P-value: 0.40019261784073884
# y_test: flipped_income
# r2-score:  -1.6854397318849235
# explained variance score:  0.003660030202236819
# Pearson-Correlation of y_test and y_pred: 0.14827224832941294
# P-value: 1.1876716765526552e-06
# Model 93
# Current Date and Time : 2025-05-10 23:15:26.436986
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0021738053106758804
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -5.243930023995386
# explained variance score:  -0.002980918101641805
# Pearson-Correlation of y_test and y_pred: 0.061556084071789495
# P-value: 0.06506109521800914
# y_test: NeighborhoodThreat
# r2-score:  -0.9552172511689261
# explained variance score:  0.002587141081793587
# Pearson-Correlation of y_test and y_pred: 0.09513216619994057
# P-value: 0.004305208488938768
# y_test: HouseholdDysfunction
# r2-score:  -0.020035718688148574
# explained variance score:  0.004356703382217053
# Pearson-Correlation of y_test and y_pred: 0.07253638510319003
# P-value: 0.029650987579125376
# y_test: flipped_income
# r2-score:  -1.6154832853274574
# explained variance score:  0.00416371928767445
# Pearson-Correlation of y_test and y_pred: 0.1734960581240846
# P-value: 1.654341838488701e-07
# Model 94
# Current Date and Time : 2025-05-10 23:15:27.223997
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.003202962746862492
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.4366922945589216
# explained variance score:  0.006735722374663244
# Pearson-Correlation of y_test and y_pred: 0.08412658214852775
# P-value: 0.013004657281711646
# y_test: NeighborhoodThreat
# r2-score:  -0.7853547115781807
# explained variance score:  0.002412015590082639
# Pearson-Correlation of y_test and y_pred: 0.11466635120089776
# P-value: 0.0006977960390707736
# y_test: HouseholdDysfunction
# r2-score:  0.0047360870691300905
# explained variance score:  0.00473609337827563
# Pearson-Correlation of y_test and y_pred: 0.09233846456322199
# P-value: 0.006389893880026331
# y_test: flipped_income
# r2-score:  -1.5069502569236524
# explained variance score:  0.0038342523180572297
# Pearson-Correlation of y_test and y_pred: 0.20530293182761183
# P-value: 9.619229044400615e-10
# Model 95
# Current Date and Time : 2025-05-10 23:15:27.957810
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0010666053396604313
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -6.07921995088298
# explained variance score:  0.009301918990928026
# Pearson-Correlation of y_test and y_pred: 0.10889078697807454
# P-value: 0.0013564360026186407
# y_test: NeighborhoodThreat
# r2-score:  -0.7355500366512726
# explained variance score:  0.0038253793815764547
# Pearson-Correlation of y_test and y_pred: 0.1389798821678638
# P-value: 4.189504193690827e-05
# y_test: HouseholdDysfunction
# r2-score:  0.00023453724944833
# explained variance score:  0.002305210941258462
# Pearson-Correlation of y_test and y_pred: 0.04913971164707428
# P-value: 0.14920377169809826
# y_test: flipped_income
# r2-score:  -1.559520853273201
# explained variance score:  0.0057929345502021334
# Pearson-Correlation of y_test and y_pred: 0.23726042172025075
# P-value: 1.653966939680187e-12
# Model 96
# Current Date and Time : 2025-05-10 23:15:28.701215
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.0011634664563600961
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.405453076582019
# explained variance score:  0.007365534806517249
# Pearson-Correlation of y_test and y_pred: 0.08711517326705373
# P-value: 0.009559094157070538
# y_test: NeighborhoodThreat
# r2-score:  -0.7222251087580294
# explained variance score:  0.001778879114656795
# Pearson-Correlation of y_test and y_pred: 0.0757535655127976
# P-value: 0.02429917740328396
# y_test: HouseholdDysfunction
# r2-score:  0.0029315287994796657
# explained variance score:  0.0034734994680535314
# Pearson-Correlation of y_test and y_pred: 0.06838198971891564
# P-value: 0.04208833949508154
# y_test: flipped_income
# r2-score:  -1.7550598109373272
# explained variance score:  0.0032292419847905762
# Pearson-Correlation of y_test and y_pred: 0.14563121666055312
# P-value: 1.3801511236314366e-05
# Model 97
# Current Date and Time : 2025-05-10 23:15:29.420591
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 7000}
# Best Score for this model:  0.0009359221577877275
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -3.037751403164732
# explained variance score:  -0.03522222257964969
# Pearson-Correlation of y_test and y_pred: -0.009289951505780372
# P-value: 0.7768796350712981
# y_test: NeighborhoodThreat
# r2-score:  -0.9797061261989641
# explained variance score:  0.000803590446613156
# Pearson-Correlation of y_test and y_pred: 0.02892190426995731
# P-value: 0.37754904243703
# y_test: HouseholdDysfunction
# r2-score:  -0.015124735946846268
# explained variance score:  -0.005208556304895584
# Pearson-Correlation of y_test and y_pred: -0.009015892587172808
# P-value: 0.7832952787829592
# y_test: flipped_income
# r2-score:  -1.771175904231042
# explained variance score:  0.0025126122317522537
# Pearson-Correlation of y_test and y_pred: 0.07135239932501647
# P-value: 0.029307983050453155
# Model 98
# Current Date and Time : 2025-05-10 23:15:30.154446
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  0.003054417765361461
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.6274995600229265
# explained variance score:  -0.020793682442130645
# Pearson-Correlation of y_test and y_pred: 0.00358736189892302
# P-value: 0.9123966519108332
# y_test: NeighborhoodThreat
# r2-score:  -1.1917689606702435
# explained variance score:  0.0020985262128873083
# Pearson-Correlation of y_test and y_pred: 0.057839113045697756
# P-value: 0.07585304738076933
# y_test: HouseholdDysfunction
# r2-score:  -0.024168578906262894
# explained variance score:  -0.005188168386041525
# Pearson-Correlation of y_test and y_pred: -0.02107662734212962
# P-value: 0.5179938932239592
# y_test: flipped_income
# r2-score:  -1.8589108618968688
# explained variance score:  0.00609860050626132
# Pearson-Correlation of y_test and y_pred: 0.16001538876878565
# P-value: 7.846677726769369e-07
# Model 99
# Current Date and Time : 2025-05-10 23:15:30.877817
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  -0.001829456540341834
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -6.0936202128724535
# explained variance score:  -0.01569089254377576
# Pearson-Correlation of y_test and y_pred: 0.029850577885203802
# P-value: 0.36422928337411975
# y_test: NeighborhoodThreat
# r2-score:  -0.7442459106919992
# explained variance score:  0.000181797184303778
# Pearson-Correlation of y_test and y_pred: 0.013621900956998605
# P-value: 0.6788908555319223
# y_test: HouseholdDysfunction
# r2-score:  -0.0023225075958765995
# explained variance score:  0.0012975316954917382
# Pearson-Correlation of y_test and y_pred: 0.03620509846515948
# P-value: 0.2710695539655711
# y_test: flipped_income
# r2-score:  -1.5676101777938825
# explained variance score:  0.002316395618846001
# Pearson-Correlation of y_test and y_pred: 0.08487772519785654
# P-value: 0.009765451280846361
# Model 100
# Current Date and Time : 2025-05-10 23:15:31.602167
# Optimising Models
# Best Parameter for this model:  {'ridge__alpha': 10000}
# Best Score for this model:  0.001004005632938032
# Evaluating Models
# y_test: PhSeAbuseSUM
# r2-score:  -1.4931813598935322
# explained variance score:  -0.0087612866919764
# Pearson-Correlation of y_test and y_pred: 0.015771715396964626
# P-value: 0.590890573730866
# y_test: NeighborhoodThreat
# r2-score:  -0.8182466202645517
# explained variance score:  0.0007106390180422473
# Pearson-Correlation of y_test and y_pred: 0.027531512395925647
# P-value: 0.3480011163546779
# y_test: HouseholdDysfunction
# r2-score:  -0.0034305275027148863
# explained variance score:  -0.0026066885496818237
# Pearson-Correlation of y_test and y_pred: -0.0019937693522045054
# P-value: 0.945825995232527
# y_test: flipped_income
# r2-score:  -1.890080595735173
# explained variance score:  0.0035959725298123635
# Pearson-Correlation of y_test and y_pred: 0.09405782949594585
# P-value: 0.0013149839454862247
#  HD in whole_group, cortical_thickness_Desikan

# %%
 #### save results:
df_opt_alpha = pd.DataFrame(opt_alpha)
df_opt_alpha.to_csv(os.path.join(full_path, "optimised_alpha.csv"), index=False)

df_r2_scores_list = pd.DataFrame(r2_scores_list)
df_r2_scores_list.to_csv(os.path.join(full_path, "r2_values.csv"), index=False)

df_explained_variance_list = pd.DataFrame(explained_variance_list)
df_explained_variance_list.to_csv(os.path.join(full_path, "explained_variance.csv"), index=False)

df_corr_coeff_list_pearson = pd.DataFrame(corr_coeff_list_pearson)
df_corr_coeff_list_pearson.to_csv(os.path.join(full_path, "corr_coeff_list_pearson.csv"), index=False)

df_corr_p_value_list_pearson = pd.DataFrame(corr_p_value_list_pearson)
df_corr_p_value_list_pearson.to_csv(os.path.join(full_path, "corr_p_value_list_pearson.csv"), index=False)

feat_imp.to_csv(os.path.join(full_path, "feature_weights.csv"), index=False)

featimp_haufev1_dataframe.to_csv(os.path.join(full_path, "feature_weights_haufe_transformed_v1_equation_6.csv"), index=False)
np.save((full_path + '/feature_weights_haufe_transformed_v1_equation_6.npy'),featimp_haufev1_dataframe)

# %%
### compute means for each variable in y_applied:

# Pre-allocate DataFrames/Series with the correct index
n_iterations = len(y_applied_datanames)  # Or however many iterations you have
index = range(n_iterations) # Or a more meaningful index if available

mean_corr_coeff_pearson = pd.Series(index=index, dtype=float)
mean_explained_variance = pd.Series(index=index, dtype=float)
mean_r2_values = pd.Series(index=index, dtype=float)

for nr_iteration in range(n_iterations):

    mean_corr_coeff_pearson.iloc[nr_iteration] = df_corr_coeff_list_pearson.iloc[nr_iteration].mean()
    mean_explained_variance.iloc[nr_iteration] = df_explained_variance_list.iloc[nr_iteration].mean()
    mean_r2_values.iloc[nr_iteration] = df_r2_scores_list.iloc[nr_iteration].mean()


# Create a dictionary of the calculated means
data = {
    'Pearson Mean': mean_corr_coeff_pearson,
    'Explained Variance Mean': mean_explained_variance,
    'R-squared Mean': mean_r2_values
}

# Create the DataFrame
df_means = pd.DataFrame(data)

# Rename rows (index) baseline
#new_row_names = ['PhSeAbuse','NHT', 'PreSubExp', 'HD', 'Scarcity', 'ParentPsych', 'SESrec']
#df_means.index = new_row_names

# Rename rows (index) baseline INR
#new_row_names = ['PhSeAbuse','NHT', 'PreSubExp', 'HD', 'Scarcity', 'ParentPsych', 'SESrec', 'INR']
#df_means.index = new_row_names

#Rename rows (index) 2yFU
new_row_names = ['PhSeAbuse','NHT', 'HD', 'SESrec']
df_means.index = new_row_names

# Rename rows (index) 4yFUeb
#new_row_names = ['NHT', 'HD', 'SESrec']
#df_means.index = new_row_names

print(f"\033[1m\033[32m\033[4m {target} in {group}, {input_type} for {time} with {rep} reps.  \033[0m") 
print(df_means)
df_means.to_csv(os.path.join(full_path , "overview_means_corrcoef_explained_variance_r2.csv"), index=True)
# Out:
#  HD in whole_group, cortical_thickness_Desikan for 2yFU with 100 reps.
#            Pearson Mean  Explained Variance Mean  R-squared Mean
# PhSeAbuse      0.026157                -0.010633       -2.942053
# NHT            0.064615                 0.001793       -1.008257
# HD             0.031151                 0.000051       -0.005048
# SESrec         0.147865                 0.004193       -1.725404

# %%
print(f"\033[1m\033[32m\033[4m {target} in {group}, {input_type} for {time}. Now run step 2 \033[0m")
# Out:
#  HD in whole_group, cortical_thickness_Desikan for 2yFU. Now run step 2

# %%
total_sample_size = len(sites)
print("Sample size")
total_sample_size
# Out:
# Sample size
# 4086
